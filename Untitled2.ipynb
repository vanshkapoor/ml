# %%
from os import listdir
from os.path import isfile,join

mypath = "./dataset/test_set/cats"


# for f in listdir(mypath):
#     if isfile(join(mypath,f)):
#         print(f)
# print(listdir(mypath))


cat_test =  [f for f in listdir(mypath) if isfile(join(mypath,f))]
# print(cat_test)


mypath2 = "./dataset/test_set/dogs"


dog_test =  [f for f in listdir(mypath2) if isfile(join(mypath2,f))]
# print(dog_test)


# print(type(dog_test))
testset = cat_test + dog_test

print(testset)
# Out:
# ['cat.4924.jpg', 'cat.4463.jpg', 'cat.4363.jpg', 'cat.4462.jpg', 'cat.4862.jpg', 'cat.4471.jpg', 'cat.4896.jpg', 'cat.4341.jpg', 'cat.4152.jpg', 'cat.4975.jpg', 'cat.4318.jpg', 'cat.4870.jpg', 'cat.4795.jpg', 'cat.4358.jpg', 'cat.4755.jpg', 'cat.4060.jpg', 'cat.4241.jpg', 'cat.4254.jpg', 'cat.4115.jpg', 'cat.4410.jpg', 'cat.4598.jpg', 'cat.4776.jpg', 'cat.4641.jpg', 'cat.4454.jpg', 'cat.4183.jpg', 'cat.4686.jpg', 'cat.4026.jpg', 'cat.4932.jpg', 'cat.4980.jpg', 'cat.4078.jpg', 'cat.4504.jpg', 'cat.4160.jpg', 'cat.4288.jpg', 'cat.4495.jpg', 'cat.4938.jpg', 'cat.4922.jpg', 'cat.4408.jpg', 'cat.4521.jpg', 'cat.4967.jpg', 'cat.4763.jpg', 'cat.4704.jpg', 'cat.4919.jpg', 'cat.4065.jpg', 'cat.4034.jpg', 'cat.4540.jpg', 'cat.4195.jpg', 'cat.4569.jpg', 'cat.4783.jpg', 'cat.4351.jpg', 'cat.4662.jpg', 'cat.4287.jpg', 'cat.4796.jpg', 'cat.4856.jpg', 'cat.4339.jpg', 'cat.4037.jpg', 'cat.4314.jpg', 'cat.4228.jpg', 'cat.4201.jpg', 'cat.4180.jpg', 'cat.4992.jpg', 'cat.4904.jpg', 'cat.4285.jpg', 'cat.
# ...

# %%
import numpy as np

np.savez('cat_and_dog_testdata',np.array(testset))

# %%
npz_file = np.load('cat_and_dog_testdata.npz')
test = npz_file['arr_0']
print(test)
# Out:
# ['cat.4924.jpg' 'cat.4463.jpg' 'cat.4363.jpg' ... 'dog.4616.jpg'
#  'dog.4898.jpg' 'dog.4109.jpg']
